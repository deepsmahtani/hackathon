# %%
import pandas as pd
import numpy as np
import seaborn as sns
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.stats.diagnostic import acorr_ljungbox
import matplotlib.pyplot as plt
import warnings

# %%
df = pd.read_csv("../../data/raw/train_test.csv")

# %%
df.week_start = pd.to_datetime(df.week_start)

# %%
df.head()
# Out:
#    store_id week_start               area_hier_desc division_hier_desc  \
# 0       124 2020-05-17      NORTHERN IRELAND REGION            IRELAND
# 1       130 2020-01-26                   MANCHESTER              NORTH
# 2       135 2019-11-17                   MERSEYSIDE              NORTH
# 3       136 2020-09-27          HOME COUNTIES SOUTH              SOUTH
# 4       176 2021-05-23  NORTH WALES, CHESHIRE & IOM            CENTRAL
#
#                  store_geography  carpark              soc_name  total_items  \
# 0               NORTHERN IRELAND      1.0           SIMPLY FOOD        66943
# 1           LANCASHIRE & CUMBRIA      0.0   LARGE - HIGH STREET        67949
# 2  MERSEYSIDE, NORTH WALES & IOM      1.0  MEDIUM - RETAIL PARK        45570
# 3            HOME COUNTIES SOUTH      1.0   MAJOR - RETAIL PARK       131658
# 4  MERSEYSIDE, NORTH WALES & IOM      1.0  MEDIUM - RETAIL PARK        56307
#
#    idle_hours  total_on_till_hours  total_transaction_count
# 0   56.657500           162.705556                     7275
# 1   64.993056           187.373333                     9460
# 2   36.532222           118.333333                     5812
# 3   80.551944           326.306944                     9168
# 4   57.786111           149.586111                     5671

# %% [markdown]
# ## Finding closed stores
#
# Some stores which are closed will have the most recent data and we can use that to filter that out:

# %%
stores_open = df[(df.week_start >= pd.to_datetime("2021-11-07")) ].store_id.unique().tolist()

# %%
stores_closed = list(set(df.store_id.unique()) - set(stores_open))

# %%
len(stores_closed)
# Out:
# 37

# %%
df_result = pd.read_csv("../../data/raw/result.csv")
df_result.week_start = pd.to_datetime(df_result.week_start, dayfirst=False)

# %%
df_result.week_start.max()
# Out:
# Timestamp('2022-02-06 00:00:00')

# %%
predict_stores = df_result.store_id.unique().tolist()

# %%
df_result_pivot = df_result.pivot_table(
    values="week_start",
    index="store_id",
    aggfunc={
        "week_start": "size"
    }
)

# %%
df_result_pivot.week_start.unique()
# Out:
# array([13, 12,  8,  4,  1, 11])

# %% [markdown]
# The data for some stores are missing in this case, we go for something like interpolation to impute the missing values:

# %%
warnings.filterwarnings("ignore")
df_out = pd.DataFrame()
date = pd.date_range("2019-11-17", periods=104, freq="W")
df_date = pd.DataFrame(date).rename(columns={0: "week_start"})
for store in predict_stores:
    if store not in stores_closed:
        try:
            print(f"Predicting for store: {store}")
            test = df[df['store_id'] == store][["week_start", "total_on_till_hours"]].set_index("week_start").sort_index()
            model = ARIMA(np.log(test), order=(1, 1, 1), freq="7D")
            results = model.fit()
            predictions = np.exp(results.forecast(13))
            preds = pd.DataFrame(predictions).rename(columns={"predicted_mean": "predicted_total_on_till_hours"})
            preds["store_id"] = store
        except ValueError:
            test.reset_index(inplace=True)
            first_date = test.iloc[0]["week_start"]
            test_new = df_date.merge(test, on="week_start", how="left")
            test_final = test_new.copy()[test_new.week_start >= first_date]
            test_final["total_on_till_hours"].interpolate(method="linear", inplace=True)
            test_final.set_index("week_start", inplace=True)
            model = ARIMA(np.log(test_final), order=(1, 1, 1), freq="7D")
            results = model.fit()
            predictions = np.exp(results.forecast(13))
            preds = pd.DataFrame(predictions).rename(columns={"predicted_mean": "predicted_total_on_till_hours"})
            preds["store_id"] = store

            
            
    df_out = pd.concat([df_out, preds])
# Out:
# Predicting for store: 660
# Predicting for store: 2114
# Predicting for store: 798
# Predicting for store: 314
# Predicting for store: 1860
# Predicting for store: 5278
# Predicting for store: 1579
# Predicting for store: 108
# Predicting for store: 369
# Predicting for store: 1889
# Predicting for store: 356
# Predicting for store: 397
# Predicting for store: 1147
# Predicting for store: 1289
# Predicting for store: 1312
# Predicting for store: 785
# Predicting for store: 848
# Predicting for store: 1961
# Predicting for store: 2642
# Predicting for store: 3308
# Predicting for store: 782
# Predicting for store: 2097
# Predicting for store: 7773
# Predicting for store: 3036
# Predicting for store: 4828
# Predicting for store: 5359
# Predicting for store: 2071
# Predicting for store: 1630
# Predicting for store: 176
# Predicting for store: 1454
# Predicting for store: 1740
# Predicting for store: 955
# Predicting for store: 779
# Predicting for store: 244
# Predicting for store: 4556
# Predicting for store: 7472
# Predicting for store: 8989
# Predicting for store: 440
# Predicting for store: 115
# Predicting for store: 296
# Predicting for store: 1291
# Predicting for store: 2723
# Predicting for store: 2914
# Predicting for store: 3120
# Predicting for store: 3780
# Predicting for store: 9182
# Predicting for store: 1178
# Predicting for store: 5297
# Predicting for store: 7799
# Predicting for store: 1888
# Predicting for store: 3528
# Predicting for store: 8853
# Predicting for store: 265
# Predicting for store: 316
# Predicting for store: 2169
# Predicting for store: 2558
# Predicting for store: 2956
# Predicting for store: 246
# Predicting for store: 802
# Predicting for store: 3557
# Predicting for store: 4323
# Predicting for store: 1029
# Predicting for store: 1460
# Predicting for store: 7265
# Predicting for store: 4747
# Predicting for store: 374
# Predicting for store: 2286
# Predicting for store: 1782
# Predicting for store: 1303
# Predicting for store: 2516
# Predicting for store: 125
# Predicting for store: 2157
# Predicting for store: 9865
# Predicting for store: 2710
# Predicting for store: 131
# Predicting for store: 4310
# Predicting for store: 38
# Predicting for store: 880
# Predicting for store: 1967
# Predicting for store: 3735
# Predicting for store: 4129
# Predicting for store: 4255
# Predicting for store: 4297
# Predicting for store: 217
# Predicting for store: 1917
# Predicting for store: 6224
# Predicting for store: 3544
# Predicting for store: 918
# Predicting for store: 1805
# Predicting for store: 1916
# Predicting for store: 1918
# Predicting for store: 152
# Predicting for store: 1180
# Predicting for store: 101
# Predicting for store: 1054
# Predicting for store: 1838
# Predicting for store: 589
# Predicting for store: 6499
# Predicting for store: 9153
# Predicting for store: 1890
# Predicting for store: 974
# Predicting for store: 2170
# Predicting for store: 754
# Predicting for store: 1096
# Predicting for store: 9124
# Predicting for store: 1940
# Predicting for store: 294
# Predicting for store: 1458
# Predicting for store: 3078
# Predicting for store: 2396
# Predicting for store: 1011
# Predicting for store: 1990
# Predicting for store: 3890
# Predicting for store: 1148
# Predicting for store: 2545
# Predicting for store: 1520
# Predicting for store: 6538
# Predicting for store: 2113
# Predicting for store: 399
# Predicting for store: 1220
# Predicting for store: 2804
# Predicting for store: 3379
# Predicting for store: 1212
# Predicting for store: 8866
# Predicting for store: 9920
# Predicting for store: 1997
# Predicting for store: 1937
# Predicting for store: 1492
# Predicting for store: 6282
# Predicting for store: 686
# Predicting for store: 9331
# Predicting for store: 1456
# Predicting for store: 3476
# Predicting for store: 1896
# Predicting for store: 1930
# Predicting for store: 2024
# Predicting for store: 2833
# Predicting for store: 2172
# Predicting for store: 6994
# Predicting for store: 776
# Predicting for store: 2736
# Predicting for store: 196
# Predicting for store: 3081
# Predicting for store: 6363
# Predicting for store: 1988
# Predicting for store: 761
# Predicting for store: 3227
# Predicting for store: 7553
# Predicting for store: 3175
# Predicting for store: 6143
# Predicting for store: 6965
# Predicting for store: 4213
# Predicting for store: 521
# Predicting for store: 6321
# Predicting for store: 3609
# Predicting for store: 6460
# Predicting for store: 128
# Predicting for store: 2066
# Predicting for store: 2600
# Predicting for store: 770
# Predicting for store: 315
# Predicting for store: 547
# Predicting for store: 2116
# Predicting for store: 130
# Predicting for store: 1455
# Predicting for store: 214
# Predicting for store: 433
# Predicting for store: 3722
# Predicting for store: 327
# Predicting for store: 2173
# Predicting for store: 992
# Predicting for store: 6541
# Predicting for store: 791
# Predicting for store: 1431
# Predicting for store: 4857
# Predicting for store: 1960
# Predicting for store: 4734
# Predicting for store: 5458
# Predicting for store: 1895
# Predicting for store: 1049
# Predicting for store: 1313
# Predicting for store: 2105
# Predicting for store: 944
# Predicting for store: 1432
# Predicting for store: 4598
# Predicting for store: 631
# Predicting for store: 709
# Predicting for store: 1938
# Predicting for store: 1989
# Predicting for store: 7252
# Predicting for store: 9030
# Predicting for store: 2312
# Predicting for store: 3683
# Predicting for store: 9836
# Predicting for store: 175
# Predicting for store: 2021

# %%
# store = 1029
# test = df[df['store_id'] == store][["week_start", "total_on_till_hours"]].set_index("week_start").sort_index()
# model = ARIMA(np.log(test), order=(1, 1, 1), freq="7D")
# results = model.fit()
# predictions = np.exp(results.forecast(13))

# %%
df_out_final = df_out.copy().reset_index().rename(columns={"index": "week_start"})

# %%
df_pre_final = df_result[["week_start", "store_id"]].merge(df_out_final, on=["week_start", "store_id"], how="left")

# %% [markdown]
# ## Check that closed stores have not been predicted for

# %%
df_pre_final[~df_pre_final.predicted_total_on_till_hours.isna()].store_id.nunique()
# Out:
# 563

# %%
set(df_pre_final[df_pre_final.predicted_total_on_till_hours.isna()].store_id.unique()) - set(stores_closed)
# Out:
# set()

# %% [markdown]
# Closed stores are given 0 as output

# %%
df_final = df_pre_final.copy().fillna(0)

# %%
df_final.to_csv("../../data/processed/final_results.csv", index=False)

# %% [markdown]
# ## Seasonal models

# %%
test_final
# Out:
#             total_on_till_hours
# week_start
# 2019-11-17            65.207778
# 2019-11-24            72.526667
# 2019-12-01            69.032222
# 2019-12-08            74.675833
# 2019-12-15            46.109444
# ...                         ...
# 2021-10-10             0.527778
# 2021-10-17             0.368611
# 2021-10-24             9.299722
# 2021-10-31             0.467778
# 2021-11-07             1.755000
#
# [104 rows x 1 columns]

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

# %%
model = SARIMAX(test_final, order=(1, 1, 1), seasonal_order=(1, 1, 1, 12))
results = model.fit()
np.exp(results.forecast(13))
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.81666D+00    |proj g|=  5.72521D-02
#
# At iterate    5    f=  2.80588D+00    |proj g|=  2.71814D-03
#
# At iterate   10    f=  2.80576D+00    |proj g|=  4.85620D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5     10     13      1     0     0   4.856D-06   2.806D+00
#   F =   2.8057632690684069
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
#  This problem is unconstrained.
# 2021-11-14      10.473954
# 2021-11-21     236.929715
# 2021-11-28      39.437467
# 2021-12-05      22.323677
# 2021-12-12      12.717770
# 2021-12-19      13.782203
# 2021-12-26      14.078755
# 2022-01-02      14.382456
# 2022-01-09      13.061282
# 2022-01-16    1508.398718
# 2022-01-23      13.458806
# 2022-01-30      27.017478
# 2022-02-06      37.475190
# Freq: W-SUN, Name: predicted_mean, dtype: float64

# %%
print(acorr_ljungbox(results.resid, lags=[10], return_df=True))
# Out:
#       lb_stat  lb_pvalue
# 10  10.892737   0.365936

# %%
store = 660
test = df[df['store_id'] == store][["week_start", "total_on_till_hours"]].set_index("week_start").sort_index()
model = ARIMA(np.log(test), order=(1, 1, 1), freq="7D")
results = model.fit()
predictions = np.exp(results.forecast(13))
preds = pd.DataFrame(predictions).rename(columns={"predicted_mean": "predicted_total_on_till_hours"})
preds["store_id"] = store
preds
# Out:
#             predicted_total_on_till_hours  store_id
# 2021-11-14                     142.385142       660
# 2021-11-21                     142.203735       660
# 2021-11-28                     142.082595       660
# 2021-12-05                     142.001671       660
# 2021-12-12                     141.947601       660
# 2021-12-19                     141.911466       660
# 2021-12-26                     141.887316       660
# 2022-01-02                     141.871175       660
# 2022-01-09                     141.860385       660
# 2022-01-16                     141.853173       660
# 2022-01-23                     141.848352       660
# 2022-01-30                     141.845129       660
# 2022-02-06                     141.842974       660

# %%
test
# Out:
#             total_on_till_hours
# week_start
# 2019-11-17           171.436111
# 2019-11-24           185.754722
# 2019-12-01           198.127222
# 2019-12-08           242.268333
# 2019-12-15           230.485833
# ...                         ...
# 2021-10-10           132.208333
# 2021-10-17           140.271667
# 2021-10-24           135.443889
# 2021-10-31           138.338611
# 2021-11-07           142.656944
#
# [104 rows x 1 columns]
